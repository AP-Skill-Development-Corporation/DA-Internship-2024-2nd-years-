# %% [markdown]
# ### File I/O

# %%
import pandas as pd

# %%
df=pd.read_csv("C://Users//meena//OneDrive//Desktop//Datasets//Salary_Data.csv")
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
df.shape
# Out:
# (6704, 6)

# %%
# to get column names from dataframe

df.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary'],
#       dtype='object')

# %%
# to get row index

df.index
# Out:
# RangeIndex(start=0, stop=6704, step=1)

# %%
# to get values from the dataframe

df.values
# Out:
# array([[32.0, 'Male', "Bachelor's", 'Software Engineer', 5.0, 90000.0],
#        [28.0, 'Female', "Master's", 'Data Analyst', 3.0, 65000.0],
#        [45.0, 'Male', 'PhD', 'Senior Manager', 15.0, 150000.0],
#        ...,
#        [30.0, 'Female', "Bachelor's Degree", 'Financial Manager', 4.0,
#         55000.0],
#        [46.0, 'Male', "Master's Degree", 'Marketing Manager', 14.0,
#         140000.0],
#        [26.0, 'Female', 'High School', 'Sales Executive', 1.0, 35000.0]],
#       dtype=object)

# %%
# to get top 5 rows

df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
# top get top 2 records

df.head(2)
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
#
#     Salary
# 0  90000.0
# 1  65000.0

# %%
# to get first record from a dataframe

df.head(1)
# Out:
#     Age Gender Education Level          Job Title  Years of Experience  \
# 0  32.0   Male      Bachelor's  Software Engineer                  5.0
#
#     Salary
# 0  90000.0

# %%
# to get bottom 5 records

df.tail(5)
# Out:
#        Age  Gender    Education Level              Job Title  \
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 6699                 20.0  200000.0
# 6700                  3.0   50000.0
# 6701                  4.0   55000.0
# 6702                 14.0  140000.0
# 6703                  1.0   35000.0

# %%
# to get last 2 records from bottom

df.tail(2)
# Out:
#        Age  Gender  Education Level          Job Title  Years of Experience  \
# 6702  46.0    Male  Master's Degree  Marketing Manager                 14.0
# 6703  26.0  Female      High School    Sales Executive                  1.0
#
#         Salary
# 6702  140000.0
# 6703   35000.0

# %%
# to get last record of a dataframe

df.tail(1)
# Out:
#        Age  Gender Education Level        Job Title  Years of Experience  \
# 6703  26.0  Female     High School  Sales Executive                  1.0
#
#        Salary
# 6703  35000.0

# %%
# to access a particular column values

df["Education Level"]
# Out:
# 0              Bachelor's
# 1                Master's
# 2                     PhD
# 3              Bachelor's
# 4                Master's
#               ...
# 6699                  PhD
# 6700          High School
# 6701    Bachelor's Degree
# 6702      Master's Degree
# 6703          High School
# Name: Education Level, Length: 6704, dtype: object

# %%
# to access  multiple columns

df[["Age","Gender"]]
# Out:
#        Age  Gender
# 0     32.0    Male
# 1     28.0  Female
# 2     45.0    Male
# 3     36.0  Female
# 4     52.0    Male
# ...    ...     ...
# 6699  49.0  Female
# 6700  32.0    Male
# 6701  30.0  Female
# 6702  46.0    Male
# 6703  26.0  Female
#
# [6704 rows x 2 columns]

# %%
# to get row with index 0

df.iloc[0]
# Out:
# Age                                 32.0
# Gender                              Male
# Education Level               Bachelor's
# Job Title              Software Engineer
# Years of Experience                  5.0
# Salary                           90000.0
# Name: 0, dtype: object

# %%
df.iloc[2]
# Out:
# Age                              45.0
# Gender                           Male
# Education Level                   PhD
# Job Title              Senior Manager
# Years of Experience              15.0
# Salary                       150000.0
# Name: 2, dtype: object

# %%
df.describe()
# Out:
#                Age  Years of Experience         Salary
# count  6702.000000          6701.000000    6699.000000
# mean     33.620859             8.094687  115326.964771
# std       7.614633             6.059003   52786.183911
# min      21.000000             0.000000     350.000000
# 25%      28.000000             3.000000   70000.000000
# 50%      32.000000             7.000000  115000.000000
# 75%      38.000000            12.000000  160000.000000
# max      62.000000            34.000000  250000.000000

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
# to get count of female and males

df["Gender"].value_counts()
# Out:
# Male      3674
# Female    3014
# Other       14
# Name: Gender, dtype: int64

# %%
df["Gender"]=="Female"
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 6699     True
# 6700    False
# 6701     True
# 6702    False
# 6703     True
# Name: Gender, Length: 6704, dtype: bool

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
# to get no of job titles

df["Job Title"].value_counts()
# Out:
# Software Engineer             518
# Data Scientist                453
# Software Engineer Manager     376
# Data Analyst                  363
# Senior Project Engineer       318
#                              ...
# Account Manager                 1
# Help Desk Analyst               1
# Senior Training Specialist      1
# Junior Web Designer             1
# Supply Chain Analyst            1
# Name: Job Title, Length: 193, dtype: int64

# %%
# to get the records of Data analyst job title

df[df["Job Title"]=="Data Analyst"]
# Out:
#        Age  Gender    Education Level     Job Title  Years of Experience  \
# 1     28.0  Female           Master's  Data Analyst                  3.0
# 81    41.0  Female           Master's  Data Analyst                 13.0
# 378   27.0  Female         Bachelor's  Data Analyst                  2.0
# 382   25.0  Female           Master's  Data Analyst                  1.0
# 386   30.0  Female         Bachelor's  Data Analyst                  5.0
# ...    ...     ...                ...           ...                  ...
# 3360  34.0    Male    Master's Degree  Data Analyst                  8.0
# 3367  35.0  Female    Master's Degree  Data Analyst                  9.0
# 3374  37.0    Male  Bachelor's Degree  Data Analyst                 11.0
# 3377  34.0    Male    Master's Degree  Data Analyst                  8.0
# 3384  35.0  Female    Master's Degree  Data Analyst                  9.0
#
#         Salary
# 1      65000.0
# 81     80000.0
# 378   110000.0
# 382   100000.0
# ...

# %%
# to update any value

df.loc[2,"Education Level"]="PHD"
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male         Bachelor's      Software Engineer
# 1     28.0  Female           Master's           Data Analyst
# 2     45.0    Male                PHD         Senior Manager
# 3     36.0  Female         Bachelor's        Sales Associate
# 4     52.0    Male           Master's               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary
# 0                     5.0   90000.0
# 1                     3.0   65000.0
# 2                    15.0  150000.0
# 3                     7.0   60000.0
# 4                    20.0  200000.0
# ...

# %%
# to get the maximum salary records

df[df["Salary"]==max(df["Salary"])]
# Out:
#        Age Gender    Education Level                 Job Title  \
# 30    50.0   Male         Bachelor's                       CEO
# 83    52.0   Male                PhD  Chief Technology Officer
# 5001  45.0   Male  Bachelor's Degree         Financial Manager
#
#       Years of Experience    Salary
# 30                   25.0  250000.0
# 83                   24.0  250000.0
# 5001                 21.0  250000.0

# %%
# sorting values based on salary


df.sort_values("Salary",ascending=False)
# Out:
#        Age  Gender    Education Level                 Job Title  \
# 83    52.0    Male                PhD  Chief Technology Officer
# 30    50.0    Male         Bachelor's                       CEO
# 5001  45.0    Male  Bachelor's Degree         Financial Manager
# 4306  51.0    Male                PhD            Data Scientist
# 4366  51.0    Male                PhD            Data Scientist
# ...    ...     ...                ...                       ...
# 172    NaN     NaN                NaN                       NaN
# 260    NaN     NaN                NaN                       NaN
# 3136  31.0    Male    Master's Degree       Full Stack Engineer
# 5247  26.0  Female  Bachelor's Degree                  Social M
# 6455  36.0    Male  Bachelor's Degree            Sales Director
#
#       Years of Experience    Salary
# 83                   24.0  250000.0
# 30                   25.0  250000.0
# 5001                 21.0  250000.0
# 4306                 24.0  240000.0
# ...

# %%
df["Job Title"].unique()
# Out:
# array(['Software Engineer', 'Data Analyst', 'Senior Manager',
#        'Sales Associate', 'Director', 'Marketing Analyst',
#        'Product Manager', 'Sales Manager', 'Marketing Coordinator',
#        'Senior Scientist', 'Software Developer', 'HR Manager',
#        'Financial Analyst', 'Project Manager', 'Customer Service Rep',
#        'Operations Manager', 'Marketing Manager', 'Senior Engineer',
#        'Data Entry Clerk', 'Sales Director', 'Business Analyst',
#        'VP of Operations', 'IT Support', 'Recruiter', 'Financial Manager',
#        'Social Media Specialist', 'Software Manager', 'Junior Developer',
#        'Senior Consultant', 'Product Designer', 'CEO', 'Accountant',
#        'Data Scientist', 'Marketing Specialist', 'Technical Writer',
#        'HR Generalist', 'Project Engineer', 'Customer Success Rep',
#        'Sales Executive', 'UX Designer', 'Operations Director',
#        'Network Engineer', 'Administrative Assistant',
# ...

# %%
len(df["Job Title"].unique())
# Out:
# 194

# %%
# Statistics

df.max()
# Out:
# C:\Users\meena\AppData\Local\Temp\ipykernel_13908\875384883.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.max()
# Age                        62.0
# Years of Experience        34.0
# Salary                 250000.0
# dtype: float64

# %%
df.min()
# Out:
# C:\Users\meena\AppData\Local\Temp\ipykernel_13908\3962516015.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.min()
# Age                     21.0
# Years of Experience      0.0
# Salary                 350.0
# dtype: float64

# %%
df.std()
# Out:
# C:\Users\meena\AppData\Local\Temp\ipykernel_13908\3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# Age                        7.614633
# Years of Experience        6.059003
# Salary                 52786.183911
# dtype: float64
